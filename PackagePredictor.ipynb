# %% [markdown]
# ## First Linear Regression  Project

# %% [markdown]
# This dataset contains only one feature column, "cgpa", which will be used to predict the target variable "package".

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import  r2_score

# %%
df=pd.read_csv('Data/placement.csv')
df.head()
# Out:
#    cgpa  package
# 0  6.89     3.26
# 1  5.12     1.98
# 2  7.82     3.25
# 3  7.42     3.67
# 4  6.94     3.57

# %%
sn.scatterplot(data=df,x='cgpa',y='package')
# Out:
# <Axes: xlabel='cgpa', ylabel='package'>

# %%
X=df[['cgpa']]
y=df['package']

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=2)

# %%
lr=LinearRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(X_test)

# %%
print(lr.score(X_test,y_test))
# Out:
# 0.780730147510384

# %%
print('R2 score',r2_score(y_test,y_pred))
# Out:
# R2 score 0.780730147510384

# %%
plt.scatter(X, y, color='blue', label='Actual')
plt.plot(X, lr.predict(X), color='red', linewidth=2, label='Regression Line')
plt.xlabel('CGPA')
plt.ylabel('Package (LPA)')
plt.title('Simple Linear Regression - CGPA vs Package')
plt.legend()
plt.grid(True)
plt.show()
